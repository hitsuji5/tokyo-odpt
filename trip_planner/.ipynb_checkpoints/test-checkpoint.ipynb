# %%
# %load_ext autoreload
# %autoreload 2
import json
import numpy as np
import pandas as pd
import folium
import matplotlib.pyplot as plt

# %%
from search_engine import search_engine

origin = search_engine.bus_network.bus_stops_location[0]
origin
# Out:
# array([  35.72456923,  139.7570725 ])

# %%
from trip_planner import BusTripPlanner

bus_trip_planner = BusTripPlanner()

# %%
journeys = bus_trip_planner.plan(origin, 0, 3600*4, 10, 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-21360992dccd> in <module>()
# ----> 1 journeys = bus_trip_planner.plan(origin, 0, 3600*4, 10, 1)
#
# /Users/Tak/work/odpt/trip_planner/trip_planner.py in plan(self, departure_point, departure_time, terminal_time, num_iters, top_k)
#      13
#      14         for iter in range(num_iters):
# ---> 15             reward, leaf, simulated_actions = utc.search()
#      16             history.append((reward, leaf, simulated_actions))
#      17
#
# /Users/Tak/work/odpt/trip_planner/mcts.py in search(self)
#      78         state = copy.copy(self.initial_state)
#      79         leaf, state = self.select_leaf(state)
# ---> 80         state, simulated_actions = self.run_simulation(state)
#      81         reward = self.get_reward(state)
#      82         return reward, leaf, simulated_actions
#
# /Users/Tak/work/odpt/trip_planner/mcts.py in run_simulation(self, state)
#     108         simulated_actions = []
#     109         while self.is_terminal(state) == False:
# --> 110             action = search_engine.get_action(state)
#     111             if action is None:
#     112                 break
#
# /Users/Tak/work/odpt/trip_planner/search_engine.py in get_action(self, state)
#      28             return None
#      29
# ---> 30         action = self.explore(state.place, stops, pois)
#      31         # if is_stop:
#      32         #     place_id, eta, route_id = stops[idx]
#
# /Users/Tak/work/odpt/trip_planner/search_engine.py in explore(self, source, stops, pois)
#      41
#      42     def explore(self, source, stops, pois):
# ---> 43         if np.random.randint(0, len(stops) + len(pois) - 1) < len(stops):
#      44             p = None
#      45             idx = np.random.choice(np.arange(len(stops)), p=p)
#
# mtrand.pyx in mtrand.RandomState.randint()
#
# ValueError: low >= high

# %%
itinerary = journeys[0]

# %%
bus_shapes = []
walk_shapes = []
for t in itinerary:
    shape = (t['start_location'], t['end_location'])
    if t['mode'] == 0:
        walk_shapes.append(shape)
    else:
        bus_shapes.append(shape)

colors = ['red', 'blue', 'green']
def plot_shape(mapp, shape, c='red', w=5):
    for point in shape:
        folium.CircleMarker(point, color=c, fill_color=c, radius=w, fill_opacity=0.8).add_to(mapp)
    folium.PolyLine(shape, color=c, weight=w, opacity=0.8).add_to(mapp)
  
center = walk_shapes[0][0]
mapp = folium.Map(location=center, zoom_start=17)
for shape in bus_shapes:
    plot_shape(mapp, shape, colors[1], 5)
    
for shape in walk_shapes:
    plot_shape(mapp, shape, colors[0], 5)
mapp
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
